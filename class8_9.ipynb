# %%
import pandas as pd

data = pd.read_excel(r'C:\users\eligi\Downloads\commerce_data.xlsx') #location from properties of file

# %%
data['discount'] = data['discount'].fillna(0)

# %%
discount_category = []

for i in range(len(data)): #len data is 2903
    if float(data['discount'][i])>0.5:
        discount_category.append('high')
    else:
        discount_category.append('low')

# %%
data['discount_binary'] = discount_category

# %%
sales_category = []

for k in range(len(data)):
    if int(data['sales'][k]) > 1000000:
        sales_category.append('good')
    else:
        sales_category.append('bad')

# %%
data['outcome'] = sales_category

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
encoder = LabelEncoder()
encoder.fit(data['discount_binary'])
data['discount_rate'] = encoder.transform(data['discount_binary'])

# %%
encoder.fit(data['outcome'])
data['y'] = encoder.transform(data['outcome'])

# %%
Y = data['y']
X = data[['discount_rate', 'likes']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state = 42, shuffle=True)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2322, 2)
# (2322,)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
len(X_test)
# Out:
# 581

# %%
y_pred = model.predict(X_test)
